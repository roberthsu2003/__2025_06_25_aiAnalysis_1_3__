# %%
#1家分站30天的營收
import numpy as np
one_store = np.random.randint(100,10000,size=(30,))
one_store
# Out:
# array([7701,  846, 6346, 3492, 9148, 8021, 6989, 9899, 1796, 3702, 8615,
#        4082, 7819, 9448, 7509, 2962, 3876, 9355, 3033, 3643, 4354, 4826,
#         150, 2169, 9235, 7108, 1279, 1150,  629, 7861])

# %%
#累計每天這家店的營收
oneStoreCum = one_store.cumsum()
oneStoreCum
# Out:
# array([  7701,   8547,  14893,  18385,  27533,  35554,  42543,  52442,
#         54238,  57940,  66555,  70637,  78456,  87904,  95413,  98375,
#        102251, 111606, 114639, 118282, 122636, 127462, 127612, 129781,
#        139016, 146124, 147403, 148553, 149182, 157043])

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(111)
axes.plot(range(1, 31), oneStoreCum, marker='o', linestyle='-', color='r', label='Cumulative Revenue')
axes.set_title('Cumulative Revenue Over Time')
axes.set_xlabel('Days')
axes.set_ylabel('Revenue')
axes.legend()
axes.grid()
plt.show()
