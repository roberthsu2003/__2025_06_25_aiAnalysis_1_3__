# %%
import numpy as np
#陣列運算
a = np.array([1, 3, 5, 7, 9])
a *= 10
a
# Out:
# array([10, 30, 50, 70, 90])

# %%
a = np.array([1, 3, 5, 7, 9])
b = np.array([2, 4 , 6, 8, 10])

#陣列運算
a + b
# Out:
# array([ 3,  7, 11, 15, 19])

# %%
#2維ndarray
arr = np.array([[1, 3, 5],[2, 4, 6]])
arr.ndim #維度
arr.shape #形狀
arr.size #元素數量
arr.dtype #型別
# Out:
# dtype('int64')

# %%
np.random.rand()
np.random.rand(30, 4)
# Out:
# array([[0.72061535, 0.9365843 , 0.64535619, 0.05568109],
#        [0.02745994, 0.85346257, 0.35556951, 0.78489834],
#        [0.81154273, 0.31648152, 0.46458138, 0.80813143],
#        [0.33639226, 0.66218175, 0.5382421 , 0.64227059],
#        [0.60787843, 0.59798854, 0.12770741, 0.33922863],
#        [0.05668568, 0.4216634 , 0.67799412, 0.12345513],
#        [0.89802422, 0.12028786, 0.65517972, 0.03819326],
#        [0.18332514, 0.31485686, 0.65995937, 0.65802437],
#        [0.68963136, 0.87079689, 0.14326168, 0.54368828],
#        [0.12842016, 0.84912961, 0.29731131, 0.91319953],
#        [0.82513251, 0.62867945, 0.95151151, 0.96326707],
#        [0.54113863, 0.25670845, 0.09996869, 0.14984893],
#        [0.73742101, 0.32575787, 0.26928705, 0.0272832 ],
#        [0.07794897, 0.81394026, 0.94658796, 0.05488823],
#        [0.54956112, 0.73488264, 0.5787312 , 0.75020962],
#        [0.73088151, 0.4702547 , 0.76492061, 0.42664743],
#        [0.60106738, 0.40146976, 0.80154757, 0.15057966],
#        [0.1636925 , 0.35195633, 0.5674707 , 0.13438897],
#        [0.47953851, 0.73628934, 0.57105304, 0.039649  ],
#        [0.26615103, 0.51011641, 0.93464053, 0.77953578],
#        [0.5062888 , 0.36433316, 0.98872441, 0.30664185],
#        [0.71706343, 0.85536567, 0.72884768, 0.17895585],
#        [0.85318998, 0.38058615, 0.24796788, 0.88000151],
#        [0.3695945 , 0.43260683, 0.63194211, 0.65357644],
#        [0.17118007, 0.06929102, 0.63510364, 0.67882876],
#        [0.76552528, 0.91416545, 0.39119201, 0.15464927],
#        [0.02435156, 0.73272471, 0.49832983, 0.77482645],
#        [0.66850544, 0.48922402, 0.27376789, 0.71345347],
#        [0.89213496, 0.3099838 , 0.25067554, 0.36750774],
#        [0.83903527, 0.86771649, 0.75700782, 0.27520922]])

# %%
scores = np.random.randint(50, 101,size=(50,5))
scores
# Out:
# array([[ 56,  68,  60,  56,  70],
#        [ 55,  85,  53,  72,  78],
#        [ 73,  81,  72,  83,  54],
#        [ 73,  64,  93,  76,  56],
#        [ 99,  84,  66,  68,  99],
#        [ 98,  92,  98,  56,  80],
#        [ 88,  97,  62,  70,  76],
#        [ 70,  99,  83,  85,  95],
#        [ 88,  57,  54, 100,  77],
#        [ 67,  73,  85,  80,  75],
#        [ 79,  68, 100,  96,  61],
#        [ 91,  61,  58,  73,  63],
#        [ 73,  61,  76,  70,  85],
#        [ 65,  58,  75,  75,  99],
#        [ 73,  98, 100,  88,  99],
#        [ 68,  75,  67,  62,  76],
#        [100,  56,  99,  93,  76],
#        [ 75,  69,  71,  53,  75],
#        [ 61,  99,  71,  55,  59],
#        [ 83,  92,  50,  98,  97],
#        [ 89,  59,  50,  51,  77],
#        [ 52,  86,  70,  80,  88],
#        [ 68,  73,  96,  53,  56],
#        [ 97,  60,  62,  79,  99],
#        [100,  67,  50,  50,  58],
#        [ 58,  77,  62,  80,  55],
#        [ 76,  94,  78,  55,  98],
#        [ 81,  84,  91,  87,  85],
#        [ 97,  67,  66,  54,  91],
#        [ 80,  88,  86,  91,  56],
#        [ 84,  54,  88,  56,  53],
#        [ 55,  75,  74,  51,  71],
#        [ 84,  77,  52,  54,  85],
#        [ 59,  78,  70,  88,  80],
#        [ 54, 100,  71,  77,  70],
#        [ 50,  57,  89,  62,  54],
#        [ 75,  97,  52,  54,  91],
#        [ 85,  63,  87,  62,  81],
#        [ 53,  67,  62,  94,  94],
#        [ 89,  69,  90, 100,  99],
#        [ 76,  63, 100,  85,  60],
#        [ 68,  60,  64,  66,  65],
#        [ 54,  51,  74,  53,  59],
#        [ 62,  59,  68,  79,  81],
#        [ 67,  93,  75,  88,  86],
#        [ 63,  78,  89,  95,  95],
#        [ 77,  98,  67,  56,  76],
#        [ 66,  95,  73,  87,  62],
#        [ 94,  58,  79,  71,  55],
#        [ 81,  70,  90,  94,  69]])
