# %%
# !pip install matplotlib
# !pip install wget
# Out:
# Requirement already satisfied: matplotlib in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: wget in /opt/miniconda3/envs/data_analysis_1_3/lib/python3.12/site-packages (3.2)

# %%
## 下載中文字型
import wget
wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %%
#載入字型
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont('ChineseFont.ttf')  # 字型檔路徑
mpl.rc('font', family='ChineseFont')

# %%
#標準寫法
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.axes import Axes

# 1.製作figure
fig:Figure = plt.figure()

# 2.在1.的figure上製作一個axes
ax_1:Axes = fig.add_subplot(1, 1, 1)
ax_1.set_title('這是一個折線圖')

# 3.將圖的數據儲存在axes中
X = [0, 1, 2]
Y = [3, 4, 5]
ax_1.plot(X, Y, color='g', marker='<', linestyle='--', linewidth=2, label='數據1', alpha=0.8, markersize=10)


# 4.顯示圖
plt.show()
